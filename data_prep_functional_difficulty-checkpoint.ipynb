# %% [markdown]
# ## goal
#
# - Analyze which region has the most severe disabilities across all types.
# - Analyze which sex in each region is most affected by severe disabilities.
# - Identify the region with the highest prevalence of specific disabilities.
# - Determine the age group most affected by specific disabilities.
# - Identify the most common disability in each province.
# - Examine the relationship between age and disability and identify common age groups for specific disabilities.
# - Determine which sex is most affected by disabilities.
# - Identify the most common disability status in each region and province.
# - Analyze regional disability statistics (maximum, minimum, and average) by province and disability status.
# - Investigate how the region of residence influences the prevalence and severity of disabilities.
# - Explore whether environmental factors contribute to disabilities.
#
#         •ok after am done with this i must be able to explain allthis like am gonna report it i front of the class•
#             must have visualization and detail explanation of why,what,how must represent how this can help in
#             preventing or recognizing each age group is in risk and which region should pay more attention
#             in taking care of disable people and prevent tha posible cause of it any format just report it

# %%
import pandas as pd 
import os
import warnings
warnings.filterwarnings("ignore")
pwd=os.getcwd()
dataset=pd.read_excel(pwd + "//functional_difficulty.xlsx").dropna().drop_duplicates()

# %%
df=dataset

# %%
df.query("Status != ['All','Mild','Moderate','Severe'] ").index      # make this better
#df=df.drop(index=[28724, 29577, 86614, 103751, 112824])
# Out:
# Index([28724, 29577, 86614, 103751, 112824], dtype='int64')

# %% [markdown]
# ## data prep

# %% [markdown]
# - [ ]  summaries by region make it small
# -  ✔    drop old codes
# - [ ]  categories age in kid,teen,adults,old
# - ✔  del other ph code left only mul since i has full code
# - [ ]  comnine province and mun by comma
# - [ ]  find a way to summarize dissability with mul
#     it be nice to find a dataset so that you can join them with mulcode,provcode

# %% [raw]
# i will drop the columns Mun,REgcode,provcdode because i can just the code for it in muncode so i will just rename that to be
# the new code
#
# i think i will use sql concat to do the
#
#
# for age to combine i need to get the lowest age for each row and pare that with the highest og age 10-14 same with others i want 4 columns
#       "kids,teen,adulta,old"
#
#
# i want to get rid of things incase of ()

# %%
df.rename(columns={"MunCode_New":"PSGC"},inplace=True)
df
# Out:
#                                                    Region  \
# 0                           National Capital Region (NCR)
# 1                           National Capital Region (NCR)
# 2                           National Capital Region (NCR)
# 3                           National Capital Region (NCR)
# 4                           National Capital Region (NCR)
# ...                                                   ...
# 117716  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 117717  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 117718  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 117719  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 117720  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
#
#                                                  Province             Mun  \
# 0       NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 1       NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 2       NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 3       NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 4       NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# ...                                                   ...             ...
# 117716                                          TAWI-TAWI          SIBUTU
# 117717                                          TAWI-TAWI          SIBUTU
# 117718                                          TAWI-TAWI          SIBUTU
# 117719                                          TAWI-TAWI          SIBUTU
# 117720                                          TAWI-TAWI          SIBUTU
#
#          RegCode_New  RegCode_Old  ProvCode_New ProvCode_Old          PSGC  \
# 0       PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 1       PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 2       PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 3       PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 4       PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# ...              ...          ...           ...          ...           ...
# 117716  PH1900000000  PH150000000  PH1907000000  PH157000000  PH1907011000
# 117717  PH1900000000  PH150000000  PH1907000000  PH157000000  PH1907011000
# 117718  PH1900000000  PH150000000  PH1907000000  PH157000000  PH1907011000
# 117719  PH1900000000  PH150000000  PH1907000000  PH157000000  PH1907011000
# 117720  PH1900000000  PH150000000  PH1907000000  PH157000000  PH1907011000
#
#         MunCode_Old                            Disability  ... Age 35 - 39  \
# 0       PH133900000     Seeing even if wearing eyeglasses  ...        6357
# 1       PH133900000     Seeing even if wearing eyeglasses  ...        5991
# 2       PH133900000     Seeing even if wearing eyeglasses  ...         305
# 3       PH133900000     Seeing even if wearing eyeglasses  ...          61
# 4       PH133900000     Seeing even if wearing eyeglasses  ...        2514
# ...             ...                                   ...  ...         ...
# 117716  PH157011000                         Communicating  ...           3
# 117717  PH157011000                         Communicating  ...           4
# 117718  PH157011000                         Communicating  ...           0
# 117719  PH157011000                         Communicating  ...           1
# 117720  PH157011000                         Communicating  ...           3
#
#        Age 40 - 44 Age 45 - 49  Age 50 - 54  Age 55 - 59  Age 60 - 64  \
# 0            10405       13993        18059        17565        18076
# 1             9886       13382        17215        16590        16996
# 2              463         559          751          905          988
# 3               56          52           93           70           92
# 4             4423        6244         8096         7736         7648
# ...            ...         ...          ...          ...          ...
# 117716           0           1            1            1            0
# 117717           6           6            4            2            2
# 117718           1           3            1            1            2
# 117719           2           2            3            0            0
# 117720           3           1            0            1            0
#
#         Age 65 - 69  Age 70 - 74  Age 75 - 79  Age 80 years and over
# 0             13756        10690         5796                   7036
# 1             12817         9839         5282                   6074
# 2               866          769          453                    829
# 3                73           82           61                    133
# 4              5613         3998         1918                   1740
# ...             ...          ...          ...                    ...
# 117716            0            0            2                      1
# 117717            1            5            5                      9
# 117718            1            3            3                      4
# 117719            0            1            2                      5
# 117720            0            1            0                      0
#
# [117715 rows x 29 columns]

# %%
df["Childern Age: 5-14"]=df["Age 5-9"] + df["Age 10-14"]
df["Adolescents: 15-19"]=df["Age 15 - 19"]
df["Young adult: Age 20 - 34"]=df["Age 20 - 24"] + df["Age 25 - 29"]+ df["Age 30 - 34"]
df["Adults: 35–54 years"]=df["Age 35 - 39"] + df["Age 40 - 44"] + df["Age 45 - 49"] + df["Age 50 - 54"]
df["Senior: over 55 years"]=df["Age 55 - 59"]  + df["Age 60 - 64"] + df["Age 65 - 69"] + df["Age 70 - 74"] + df["Age 75 - 79"] + df['Age 80 years and over'] 
df.head()
# Out:
#                           Region  \
# 0  National Capital Region (NCR)
# 1  National Capital Region (NCR)
# 2  National Capital Region (NCR)
# 3  National Capital Region (NCR)
# 4  National Capital Region (NCR)
#
#                                             Province             Mun  \
# 0  NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 1  NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 2  NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 3  NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
# 4  NCR, City of Manila, First District (Not a Pro...  CITY OF MANILA
#
#     RegCode_New  RegCode_Old  ProvCode_New ProvCode_Old          PSGC  \
# 0  PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 1  PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 2  PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 3  PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
# 4  PH1300000000  PH130000000  PH1380600000  PH133900000  PH1380600000
#
#    MunCode_Old                            Disability  ... Age 60 - 64  \
# 0  PH133900000     Seeing even if wearing eyeglasses  ...       18076
# 1  PH133900000     Seeing even if wearing eyeglasses  ...       16996
# 2  PH133900000     Seeing even if wearing eyeglasses  ...         988
# 3  PH133900000     Seeing even if wearing eyeglasses  ...          92
# 4  PH133900000     Seeing even if wearing eyeglasses  ...        7648
#
#   Age 65 - 69 Age 70 - 74  Age 75 - 79  Age 80 years and over  \
# 0       13756       10690         5796                   7036
# 1       12817        9839         5282                   6074
# 2         866         769          453                    829
# 3          73          82           61                    133
# 4        5613        3998         1918                   1740
#
#    Childern Age: 5-14  Adolescents: 15-19  Young adult: Age 20 - 34  \
# 0                4537                5248                     20600
# 1                4057                4779                     19025
# 2                 335                 416                      1383
# 3                 145                  53                       192
# 4                2173                1981                      8148
#
#    Adults: 35–54 years  Senior: over 55 years
# 0                48814                  72919
# 1                46474                  67598
# 2                 2078                   4810
# 3                  262                    511
# 4                21277                  28653
#
# [5 rows x 34 columns]

# %%
#df["Disability"].str.rstrip(r"^(\ \b).*").unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12096\797181926.py in ?()
#       1 #df["Disability"].str.rstrip(r"^(\ \b).*").unique()
# ----> 2 df.str.strip(" ")
#
# c:\Users\kian\PycharmProjects\DSP\project1\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
dftest=df.copy()

df["Disability"].replace(['Seeing even if wearing eyeglasses',
               'Hearing even if using a hearing aid',
               'Walking or climbing steps',
               'Remembering or concentrating','Self-caring (washing all over or dressing)',"Communicating"],
["Visual Disability","Hearing Disability","Mobility Disability","Cognitive Disability","Self-Care Disability","Communication Disability"],inplace=True)

# %%
df.Disability.unique()
# Out:
# array(['VISUAL DISABILITY', 'HEARING DISABILITY', 'MOBILITY DISABILITY',
#        'COGNITIVE DISABILITY', 'SELF-CARE DISABILITY',
#        'COMMUNICATION DISABILITY'], dtype=object)

# %%
df['Sex'].replace("Both Sexes","All Sex",inplace=True)
