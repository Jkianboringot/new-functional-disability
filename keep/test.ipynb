# %%
def greet(name):
    return name
def add(a,b):
    return a+b
greet('jkin')
import os

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: c:\Users\kian\PycharmProjects\DSP\project1\functional_difficulty_dataset\keep
