# %% [markdown]
# ## goal
# - bring attention to the people which province that needs more help in dealing with a certain disability
#     why:
#       to help riase awareness so to this people and help them get notice by goverment and raise funding
#           to help heal or aliviaite thier pain

# %% [markdown]
# ## task
# - Analyze which region has the most severe disabilities across all types.  ✔
# ###   •Prevalence: Calculate as (cases / total population) × 100 for fair comparisons.
# ###   •Most affected: Compare rates (e.g., per 1,000 people) rather than raw counts to avoid population size bias.
# - Analyze which sex in each region is most affected by severe disabilities. ✔✔
# - Identify the region with the highest prevalence of specific disabilities.  ✔
# - Determine the age group most affected by specific disabilities.
# - Identify the most common disability in each province.
# - Determine which sex is most affected by disabilities.
# - Identify the most common disability status in each region and province.
# - Analyze regional disability statistics (maximum, minimum, and average) by province and disability status.
# - Investigate how the region of residence influences the prevalence and severity of disabilities.
# - "Do certain disabilities cluster in specific age groups (e.g., mobility issues in ages 55+)?"
# - "Is there a correlation between age and number of concurrent disabilities?"
#
#
#         •ok after am done with this i must be able to explain allthis like am gonna report it i front of the class•
#             must have visualization and detail explanation of why,what,how must represent how this can help in
#             preventing or recognizing each age group is in risk and which region should pay more attention
#             in taking care of disable people and prevent tha posible cause of it any format just report it
#
#         •i need to follow what below and be more mindfull of what i do i need to consider alot of thing that the one below
#           will be some kind of guide line

# %% [raw]
# The questions are **good starting points** but need refinement to ensure clarity, avoid redundancy, and align with the dataset’s variables (age groups, disability types, regions). Here’s a critique and suggestions for improvement:
#
# ---
#
# ### **Strengths**
# 1. **Coverage**: Addresses key dimensions (region, sex, age, disability type).
# 2. **Actionability**: Focuses on actionable insights (e.g., targeting interventions by region/sex).
# 3. **Specificity**: Ties analysis to granular variables (e.g., province-level data).
#
# ---
#
# ### **Areas for Improvement**
#
# #### **1. Ambiguous Terminology**
# - **Issue**: Terms like "most severe," "most affected," and "prevalence" lack clear definitions.
# - **Fix**: Define metrics upfront. For example:
#   - **Severity**: Use ordscalinal es (e.g., "severe" vs. "moderate") or proxy metrics (e.g., number of disability types per person).
#   - **Prevalence**: Calculate as `(cases / total population) × 100` for fair comparisons.
#   - **Most affected**: Compare rates (e.g., per 1,000 people) rather than raw counts to avoid population size bias.
#
# #### **2. Redundancy**
# - **Issue**: Overlapping questions (e.g., "sex most affected" vs. "sex in each region most affected").
# - **Fix**: Streamline questions to avoid duplication:
#   - Merge "Determine which sex is most affected by disabilities" and "Analyze which sex in each region is most affected by severe disabilities."
#   - Combine "Identify the most common disability in each province" and "Identify the region with the highest prevalence of specific disabilities."
#
# #### **3. Missing Context**
# - **Issue**: No questions about **age-disability interaction** (e.g., "Do older age groups have more comorbidities?").
# - **Fix**: Add questions like:
#   - "Do certain disabilities cluster in specific age groups (e.g., mobility issues in ages 55+)?"
#   - "Is there a correlation between age and number of concurrent disabilities?"
#
# #### **4. Statistical Rigor**
# - **Issue**: Questions lack hypotheses or methods (e.g., "How do we define ‘relationship’ between age and disability?").
# - **Fix**: Reframe questions to include analysis methods:
#   - "Use chi-square tests to determine if disability type X is statistically more prevalent in Region Y."
#   - "Calculate odds ratios to quantify how age increases the likelihood of disability Z."
#
# #### **5. Environmental Factors**
# - **Issue**: The dataset lacks explicit environmental variables (e.g., pollution, healthcare access).
# - **Fix**: If "region" is a proxy for environmental factors, rephrase the question:
#   - "Do regions with lower socioeconomic status (inferred from data) correlate with higher disability rates?"
#
# ---
#
# ### **Revised Questions**
# 1. **Regional Analysis**
#    - "Which region has the highest age-adjusted prevalence of severe disabilities (≥2 types)?"
#    - "Do disability types vary significantly by region (test with p < 0.05)?"
#
# 2. **Sex & Demographics**
#    - "Are males or females more likely to have severe disabilities (odds ratio) in Region X?"
#    - "Does the sex-disability relationship vary by age group (stratified analysis)?"
#
# 3. **Age-Specific Insights**
#    - "Which age group (5–18, 19–35, 36–55, 55+) has the highest prevalence of mobility-related disabilities?"
#    - "Is there a trend in disability onset age for sensory vs. cognitive disabilities?"
#
# 4. **Province-Level Focus**
#    - "Which province has the highest rate of [specific disability] compared to the national average?"
#    - "Are there provinces where >20% of the population has multiple disabilities?"
#
# 5. **Environmental Proxy**
#    - "Do urban provinces have higher rates of mental health-related disabilities than rural ones?"
#
# ---
#
# ### **Key Considerations**
# - **Normalization**: Always adjust for population size (e.g., rates per 1,000).
# - **Confounding Variables**: Control for age/sex when comparing regions.
# - **Statistical Tests**: Use hypothesis testing (e.g., t-tests, ANOVA) to validate findings.
#
# These adjustments will turn your questions into a **robust analytical framework**! 📊

# %%
import pandas as pd 
import os
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pwd=os.getcwd()
dataset=pd.read_csv(pwd + "//clean_functional_difficulty.csv")
dataset.drop(columns=["PSGC",'Unnamed: 0'])
region_total_population=pd.read_csv("region_total_population.csv")
# Out:
#                                                    Region        Province  \
# 0                                 National Capital Region  First District
# 1                                 National Capital Region  First District
# 2                                 National Capital Region  First District
# 3                                 National Capital Region  First District
# 4                                 National Capital Region  First District
# ...                                                   ...             ...
# 117705  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...       TAWI-TAWI
# 117706  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...       TAWI-TAWI
# 117707  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...       TAWI-TAWI
# 117708  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...       TAWI-TAWI
# 117709  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...       TAWI-TAWI
#
#                       Disability      Sex    Status  \
# 0              Visual Disability  All Sex       All
# 1              Visual Disability  All Sex      Mild
# 2              Visual Disability  All Sex  Moderate
# 3              Visual Disability  All Sex    Severe
# 4              Visual Disability     Male       All
# ...                          ...      ...       ...
# 117705  Communication Disability     Male    Severe
# 117706  Communication Disability   Female       All
# 117707  Communication Disability   Female      Mild
# 117708  Communication Disability   Female  Moderate
# 117709  Communication Disability   Female    Severe
#
#         Household Population 5 Years Old and Over with Functional Difficulty  \
# 0                                                  152118
# 1                                                  141933
# 2                                                    9022
# 3                                                    1163
# 4                                                   62232
# ...                                                   ...
# 117705                                                 13
# 117706                                                 63
# 117707                                                 24
# 117708                                                 18
# 117709                                                 21
#
#         Childern Age: 5-14  Adolescents: 15-19  Young adult: Age 20 - 34  \
# 0                     4537                5248                     20600
# 1                     4057                4779                     19025
# 2                      335                 416                      1383
# 3                      145                  53                       192
# 4                     2173                1981                      8148
# ...                    ...                 ...                       ...
# 117705                   1                   1                         2
# 117706                   7                   3                         9
# 117707                   1                   0                         4
# 117708                   0                   1                         1
# 117709                   6                   2                         4
#
#         Adults: 35–54 years  Senior: over 55 years
# 0                     48814                  72919
# 1                     46474                  67598
# 2                      2078                   4810
# 3                       262                    511
# 4                     21277                  28653
# ...                     ...                    ...
# 117705                    5                      4
# 117706                   20                     24
# 117707                    5                     14
# 117708                    8                      8
# 117709                    7                      2
#
# [117710 rows x 11 columns]

# %%
df=dataset
df.head()
df["Region"]=df["Region"].str.strip()
df.rename(columns={"Household Population 5 Years Old and Over with Functional Difficulty":"5 Years and Over with Functional Difficulty"},inplace=True)

# %%
region_total_population["Region"]=region_total_population["Region"].str.upper()

# %%
disability_by_region = (
    df.loc[(df["Sex"] == "All Sex") & (df["Status"] == "Severe")]
    .groupby(["Disability", "Region"], as_index=False)["5 Years and Over with Functional Difficulty"]
    .sum()
    .assign(
        Region=lambda x: x["Region"]
        .str.upper()
        .str.replace("^NATIONAL CAPITAL REGION$", "NATIONAL CAPITAL REGION (NCR)", regex=True)
    )
)

# %%
total_severe_disability_population=pd.merge(disability_by_region,region_total_population,on="Region",how="left")
total_disability_population["Person affected by disability per 100k"]=(total_disability_population['5 Years and Over with Functional Difficulty']
                                                                       /total_disability_population['Population']
                                                                       * 100000)


total_disability_population=pd.merge(disability_by_region,region_total_population,on="Region",how="left")

# %%
# Out:
#                Disability                                             Region  \
# 0    Cognitive Disability  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 1    Cognitive Disability             CORDILLERA ADMINISTRATIVE REGION (CAR)
# 2    Cognitive Disability                                    MIMAROPA REGION
# 3    Cognitive Disability                      NATIONAL CAPITAL REGION (NCR)
# 4    Cognitive Disability                           REGION XI (DAVAO REGION)
# ..                    ...                                                ...
# 97      Visual Disability                        REGION VI (WESTERN VISAYAS)
# 98      Visual Disability                       REGION VII (CENTRAL VISAYAS)
# 99      Visual Disability                      REGION VIII (EASTERN VISAYAS)
# 100     Visual Disability                       REGION X (NORTHERN MINDANAO)
# 101     Visual Disability                               REGION XIII (CARAGA)
#
#      5 Years and Over with Functional Difficulty  Population  \
# 0                                            662     4404288
# 1                                           1187     1797660
# 2                                           2002     3228558
# 3                                           4899    13484462
# 4                                           2676     5243536
# ..                                           ...         ...
# 97                                          6928     7954723
# 98                                          6407     8081988
# 99                                          3860     4547150
# 100                                         2985     5022768
# 101                                         1753     2804788
#
#      Person affected by disability per 100k
# 0                                 15.030806
# 1                                 66.030284
# 2                                 62.009107
# 3                                 36.330704
# 4                                 51.034264
# ..                                      ...
# 97                                87.092913
# 98                                79.275050
# 99                                84.888337
# 100                               59.429382
# 101                               62.500267
#
# [102 rows x 5 columns]

# %%
# Out:
#                                                  Region  Status  \
# 69    BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 138              Cordillera Administrative Region (CAR)  Severe
# 210                                     MIMAROPA Region  Severe
# 282                             National Capital Region  Severe
# 354                            REGION XI (DAVAO REGION)  Severe
# 426                           REGION XII (SOCCSKSARGEN)  Severe
# 498                            Region I (Ilocos Region)  Severe
# 570                          Region II (Cagayan Valley)  Severe
# 642                          Region III (Central Luzon)  Severe
# 714                            Region IV-A (CALABARZON)  Severe
# 786                     Region IX (Zamboanga Peninsula)  Severe
# 858                             Region V (Bicol Region)  Severe
# 930                         Region VI (Western Visayas)  Severe
# 1002                       Region VII (Central Visayas)  Severe
# 1074                      Region VIII (Eastern Visayas)  Severe
# 1146                       Region X (Northern Mindanao)  Severe
# 1218                               Region XIII (Caraga)  Severe
#
#                 Disability      Sex  \
# 69       Visual Disability  All Sex
# 138   Self-Care Disability  All Sex
# 210   Self-Care Disability  All Sex
# 282   Self-Care Disability  All Sex
# 354   Self-Care Disability  All Sex
# 426   Self-Care Disability  All Sex
# 498   Self-Care Disability  All Sex
# 570   Self-Care Disability  All Sex
# 642   Self-Care Disability  All Sex
# 714   Self-Care Disability  All Sex
# 786   Self-Care Disability  All Sex
# 858   Self-Care Disability  All Sex
# 930   Self-Care Disability  All Sex
# 1002  Self-Care Disability  All Sex
# 1074  Self-Care Disability  All Sex
# 1146  Self-Care Disability  All Sex
# 1218  Self-Care Disability  All Sex
#
#       5 Years and Over with Functional Difficulty
# 69                                           3654
# 138                                          3439
# 210                                          5640
# 282                                         12166
# 354                                          6877
# 426                                         10032
# 498                                         10350
# 570                                          6285
# 642                                         14358
# 714                                         17912
# 786                                          5349
# 858                                         12000
# 930                                         14902
# 1002                                        13565
# 1074                                         8608
# 1146                                         7462
# 1218                                         4588

# %%
=(df.loc[(df["Sex"] != 'All Sex') & (df["Status"] == 'Severe')]
                 .groupby(["Region""Sex"],as_index=False)["5 Years and Over with Functional Difficulty"].sum())

# %%
gender_severety=(df.loc[(df["Sex"] != 'All Sex') & (df["Status"] == 'Severe')]
                 .groupby(["Region","Sex","Disability"],as_index=False)
                 ["5 Years and Over with Functional Difficulty"]
                 .sum().assign(Region=lambda x:x["Region"].str.upper()
                .str.replace("^NATIONAL CAPITAL REGION$", "NATIONAL CAPITAL REGION (NCR)", regex=True)))



gender_disability=pd.merge(gender_severety,region_total_population,on="Region",how="left").assign(population=lambda x:x["Population"]/2)
gender_disability["Gender affected by disability per 100k"]=gender_disability["5 Years and Over with Functional Difficulty"]/(gender_disability['Population']/2)*100000
gender_disability.rename(columns={"Population":"Total Population"},inplace=True)
gender_disability.rename(columns={"population":"50/50 Population"},inplace=True)

# %%
# Out:
#                                                 Region     Sex  \
# 0    BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Female
# 1    BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Female
# 2    BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Female
# 3    BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Female
# 4    BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Female
# ..                                                 ...     ...
# 199                               REGION XIII (CARAGA)    Male
# 200                               REGION XIII (CARAGA)    Male
# 201                               REGION XIII (CARAGA)    Male
# 202                               REGION XIII (CARAGA)    Male
# 203                               REGION XIII (CARAGA)    Male
#
#                    Disability  5 Years and Over with Functional Difficulty  \
# 0        Cognitive Disability                                          367
# 1    Communication Disability                                         1878
# 2          Hearing Disability                                          288
# 3         Mobility Disability                                          495
# 4        Self-Care Disability                                         1158
# ..                        ...                                          ...
# 199  Communication Disability                                         1913
# 200        Hearing Disability                                          963
# 201       Mobility Disability                                         1916
# 202      Self-Care Disability                                         2229
# 203         Visual Disability                                          787
#
#      Total Population  50/50 Population  \
# 0             4404288         2202144.0
# 1             4404288         2202144.0
# 2             4404288         2202144.0
# 3             4404288         2202144.0
# 4             4404288         2202144.0
# ..                ...               ...
# 199           2804788         1402394.0
# 200           2804788         1402394.0
# 201           2804788         1402394.0
# 202           2804788         1402394.0
# 203           2804788         1402394.0
#
#      Gender affected by disability per 100k
# 0                                 16.665577
# 1                                 85.280527
# 2                                 13.078164
# 3                                 22.478094
# 4                                 52.585117
# ..                                      ...
# 199                              136.409597
# 200                               68.668292
# 201                              136.623517
# 202                              158.942494
# 203                               56.118323
#
# [204 rows x 7 columns]

# %%
gender_severety=region_distribution.query("Sex != 'All Sex' & Status == 'Severe'")
gender_severety=gender_severety.loc[gender_severety.groupby(["Region","Disability"])["5 Years and Over with Functional Difficulty"].idxmax()]
gender_severety.head(34)
# Out:
#                                                 Region  Status  \
# 55   BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 58   BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 62   BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 64   BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 68   BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 70   BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  Severe
# 127             Cordillera Administrative Region (CAR)  Severe
# 131             Cordillera Administrative Region (CAR)  Severe
# 134             Cordillera Administrative Region (CAR)  Severe
# 136             Cordillera Administrative Region (CAR)  Severe
# 139             Cordillera Administrative Region (CAR)  Severe
# 142             Cordillera Administrative Region (CAR)  Severe
# 199                                    MIMAROPA Region  Severe
# 203                                    MIMAROPA Region  Severe
# 206                                    MIMAROPA Region  Severe
# 208                                    MIMAROPA Region  Severe
# 211                                    MIMAROPA Region  Severe
# 214                                    MIMAROPA Region  Severe
# 271                            National Capital Region  Severe
# 274                            National Capital Region  Severe
# 277                            National Capital Region  Severe
# 280                            National Capital Region  Severe
# 283                            National Capital Region  Severe
# 286                            National Capital Region  Severe
# 344                           REGION XI (DAVAO REGION)  Severe
# 347                           REGION XI (DAVAO REGION)  Severe
# 350                           REGION XI (DAVAO REGION)  Severe
# 352                           REGION XI (DAVAO REGION)  Severe
# 355                           REGION XI (DAVAO REGION)  Severe
# 358                           REGION XI (DAVAO REGION)  Severe
# 415                          REGION XII (SOCCSKSARGEN)  Severe
# 419                          REGION XII (SOCCSKSARGEN)  Severe
# 422                          REGION XII (SOCCSKSARGEN)  Severe
# 424                          REGION XII (SOCCSKSARGEN)  Severe
#
#                    Disability     Sex  \
# 55       Cognitive Disability  Female
# 58   Communication Disability  Female
# 62         Hearing Disability    Male
# 64        Mobility Disability  Female
# 68       Self-Care Disability    Male
# 70          Visual Disability  Female
# 127      Cognitive Disability  Female
# 131  Communication Disability    Male
# 134        Hearing Disability    Male
# 136       Mobility Disability  Female
# 139      Self-Care Disability  Female
# 142         Visual Disability  Female
# 199      Cognitive Disability  Female
# 203  Communication Disability    Male
# 206        Hearing Disability    Male
# 208       Mobility Disability  Female
# 211      Self-Care Disability  Female
# 214         Visual Disability  Female
# 271      Cognitive Disability  Female
# 274  Communication Disability  Female
# 277        Hearing Disability  Female
# 280       Mobility Disability  Female
# 283      Self-Care Disability  Female
# 286         Visual Disability  Female
# 344      Cognitive Disability    Male
# 347  Communication Disability    Male
# 350        Hearing Disability    Male
# 352       Mobility Disability  Female
# 355      Self-Care Disability  Female
# 358         Visual Disability  Female
# 415      Cognitive Disability  Female
# 419  Communication Disability    Male
# 422        Hearing Disability    Male
# 424       Mobility Disability  Female
#
#      5 Years and Over with Functional Difficulty
# 55                                           367
# 58                                          1878
# 62                                           337
# 64                                           495
# 68                                          1292
# 70                                          1872
# 127                                          626
# 131                                         1217
# 134                                          640
# 136                                         1580
# 139                                         1824
# 142                                          749
# 199                                         1038
# 203                                         2088
# 206                                         1080
# 208                                         2660
# 211                                         2959
# 214                                         1242
# 271                                         2481
# 274                                         5982
# 277                                         2630
# 280                                         6034
# 283                                         6573
# 286                                         3376
# 344                                         1390
# 347                                         3015
# 350                                         1346
# 352                                         3088
# 355                                         3463
# 358                                         1562
# 415                                         1984
# 419                                         4117
# 422                                         1944
# 424                                         4668

# %%
gender_severety.groupby(["Region",])["5 Years and Over with Functional Difficulty"].sum()

highest_regional_disability.query("Region == 'Cordillera Administrative Region (CAR)' ")
# Out:
# Empty DataFrame
# Columns: [Region, Status, Disability, Sex, 5 Years and Over with Functional Difficulty]
# Index: []
